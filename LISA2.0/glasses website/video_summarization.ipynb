# %%
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi

# %%
youtube_vid="https://www.youtube.com/watch?v=08qwI9RX8-M&list=PLyqSpQzTE6M9LibNqhhCYLDvfVGhcRDN4&index=3"

# %%
vid_id=youtube_vid.split("=")[1]

# %%
vid_id
# Out:
# '08qwI9RX8-M&list'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(vid_id)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/08qwI9RX8-M&list"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
YouTubeTranscriptApi.get_transcript(vid_id)
transcript=YouTubeTranscriptApi.get_transcript(vid_id)

# %%
transcript[0:5]
# Out:
# [{'text': '[Music]', 'start': 1.38, 'duration': 5.429},
#  {'text': '[Music]', 'start': 9.78, 'duration': 3.41},
#  {'text': 'now', 'start': 41.6, 'duration': 2.959},
#  {'text': 'if you see from the computation engine',
#   'start': 42.64,
#   'duration': 3.919},
#  {'text': 'the processors okay so', 'start': 44.559, 'duration': 5.121}]

# %%
result=""
for i in transcript:
  result+=' '+i['text']
print(len(result))
# Out:
# 23688

# %%
summarizer=pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# c:\Users\sshiv\anaconda3\envs\tf-gpu\lib\site-packages\huggingface_hub\file_download.py:123: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sshiv\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
num_iters=int(len(result)/1000)
summarized_text=[]
for i in range(0,num_iters+1):
  start=0
  start=i*1000
  end=(i+1)*1000
  out=summarizer(result[start:end])
  out=out[0]
  out=out['summary_text']
  summarized_text.append(out)
print(summarized_text)
# Out:
# Your max_length is set to 142, but you input_length is only 127. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# [" You cannot increase the clock speed anymore due to the end of donor scaling and the power volume is hitting and that's why you cannot get more than a particular fixed clock frequency that is available nowadays in the processors or computation engines . What the traditional systems or or or the modern systems are going towards is that this heterogeneous computing .", ' The tradition is what divide your task into different subtasks and of course this this this is data parallel workloads so mostly this ai benchmarks that we are talking about are mostly data intensive . Ch which are not that much of data intensive they are being controlled or they have been executed by the processor itself so that might be multi-core processor single core processor .', ' The main important thing is that we have now accelerators uh uh in the system in the computing system uh with along with the processors . The air benchmarks or ei algorithms will be executed by these accelerators so that is why we are talking about gpus and because uh because of what that you will see in the in the . subsequent slides but that is that is the main . take away from this slide so now what kind of ah accelerators that are available nowadays are .', ' A6 processors are highly specialized only for uh only for ei benchmarks here we talk about ai based a6 of course for any other application domain you can have different a6 as well and we have a6 gpus which are graphics processing unit graphical processing units . A6 can give you the flexibility to run both ai benchmarks as well as video or graphics benchmarks .', ' Data type and accuracy that you have seen for the ei benchmarks have very close relations okay so that relationship we will talk about and you have your gpu inked also eight in eight means eight bit integer units okay . Gpu is a much more generalized in terms of it it can both accelerate your uh ei bh max as well as your video p. is data type .', ' This eon line is the train for your gpu ap332 which is almost generalized uh gpus that you can get in the in the market nowadays and and very of a few are so basically if you see that integer eight so basically these are with having these gpus with rtx 2080 t4 v100 .', " Different sizes of feature map that is able now you want to have much more drops per millimeter square okay . You want to accommodate much more compute or or you . want to achieve much more complete density uh uh available for your systems so you will go for a lower feature size which is let's say seven nanometer by eight nanometer that is available .", ' The size of this diamonds specify what kind of feature map they are using now with decreasing the feature maps that means you can accommodate more compute units inside your chip right so that means . decreasing feature maps means you . can . accommodate more units inside their chip right . That means . you can increase the performance density cops per millimeter square right so how far you can go of course you cannot go beyond certain limit .', ' Will be achieved by lower feature map success. will be achieved . Will be able to achieve by lowering feature maps success . Will also be possible to increase the number of gigaflops per second that you are actually much more so currently we have ampere series of of nvidia series of n Nvidia .', ' In the next lecture we will see some abstraction of some features of these modern uh gpu which are available and also modern modern s6 . We will see a much more clearer area like in a very coarser area like what are the things available and how you can program them in the in the . next lecture .', ' System has l2 cache also has dynamic memory or dram so which is this a hp m2 that you are seeing here and the theory interface that is available on this particular systems now . System\xa0increase in the number of cores that can be accommodated into into into one particular system in two years .', " tensor cores for machine learning is available in your holder serie ...

# %%
print(len(summarized_text))
# Out:
# 24

# %%
summarized_text
# Out:
# [" You cannot increase the clock speed anymore due to the end of donor scaling and the power volume is hitting and that's why you cannot get more than a particular fixed clock frequency that is available nowadays in the processors or computation engines . What the traditional systems or or or the modern systems are going towards is that this heterogeneous computing .",
#  ' The tradition is what divide your task into different subtasks and of course this this this is data parallel workloads so mostly this ai benchmarks that we are talking about are mostly data intensive . Ch which are not that much of data intensive they are being controlled or they have been executed by the processor itself so that might be multi-core processor single core processor .',
#  ' The main important thing is that we have now accelerators uh uh in the system in the computing system uh with along with the processors . The air benchmarks or ei algorithms will be executed by these accelerators so that is why we are talking about gpus and because uh because of what that you will see in the in the . subsequent slides but that is that is the main . take away from this slide so now what kind of ah accelerators that are available nowadays are .',
#  ' A6 processors are highly specialized only for uh only for ei benchmarks here we talk about ai based a6 of course for any other application domain you can have different a6 as well and we have a6 gpus which are graphics processing unit graphical processing units . A6 can give you the flexibility to run both ai benchmarks as well as video or graphics benchmarks .',
#  ' Data type and accuracy that you have seen for the ei benchmarks have very close relations okay so that relationship we will talk about and you have your gpu inked also eight in eight means eight bit integer units okay . Gpu is a much more generalized in terms of it it can both accelerate your uh ei bh max as well as your video p. is data type .',
#  ' This eon line is the train for your gpu ap332 which is almost generalized uh gpus that you can get in the in the market nowadays and and very of a few are so basically if you see that integer eight so basically these are with having these gpus with rtx 2080 t4 v100 .',
#  " Different sizes of feature map that is able now you want to have much more drops per millimeter square okay . You want to accommodate much more compute or or you . want to achieve much more complete density uh uh available for your systems so you will go for a lower feature size which is let's say seven nanometer by eight nanometer that is available .",
#  ' The size of this diamonds specify what kind of feature map they are using now with decreasing the feature maps that means you can accommodate more compute units inside your chip right so that means . decreasing feature maps means you . can . accommodate more units inside their chip right . That means . you can increase the performance density cops per millimeter square right so how far you can go of course you cannot go beyond certain limit .',
#  ' Will be achieved by lower feature map success. will be achieved . Will be able to achieve by lowering feature maps success . Will also be possible to increase the number of gigaflops per second that you are actually much more so currently we have ampere series of of nvidia series of n Nvidia .',
#  ' In the next lecture we will see some abstraction of some features of these modern uh gpu which are available and also modern modern s6 . We will see a much more clearer area like in a very coarser area like what are the things available and how you can program them in the in the . next lecture .',
#  ' System has l2 cache also has dynamic memory or dram so which is this a hp m2 that you are seeing here and the theory interface that is available on this particular systems now . System\xa0increase in the number of cores that can be accommodated into into into one particular system in two years .',
#  " tensor cores for machine learning is available in your holder series in the n Nvidia v100 as well as your ampere sales . This is having new floating point data type as tf 32 okay so that gives a bit more flexibility in terms of model training or benchmark training that that we'll be discussing in in the coming classes .",
#  ' Tensorflow actually does this matrix multiplication in one side so basically four cross four one matrix multiplication will be done in one second one clock cycle to be precise now . The main engine is the convolution range and the conf conf. vidual units for mac operations so all these are mac units .',
#  ' Tensor cores can perform the entire tensor of like set of input data so basically these two sets of data you can see 16 across 16 plus you can accumulate another 16 which is already there so in the in the accumulator and you will get the data of system uh or entire .',
#  ' Modern gps that are coming with more number of tensor force is even much more flexible than the earlier skills so there is a notion of sparsity in inside your uh training or or inference in your ai benchmarks so what is sparsit sparsity means  you can have multiple weights or parameters which are very close to zero can be interpreted as as zero .',
#  " Sparsity and matrix multiplication is introduced in this tensor force that will available in ampere series . for those particular half number of multiplication so that means uh of course that will be manifold for uh for your 2d matrix multiplication but you get the idea right so so basically for where one operand is zero you just don't don't do the multiplication .",
#  ' Mixed precision means in the in the whole computation engine you can you can have 8 to 32 bits of of multiplying and and and with full precision full means the double precision you can get of uh more performance density in in in 32 bit and even more you can go for mixed precision so precision compute density .',
#  ' In terms of apga based accelerators apgs are fully reconfigurable and and and this is the abbreviation of pre-programmable gateways which are free programmable miss . o beyond one nanometer it is very difficult because the the energy the the the temperature that will be generated by the process of processing engines will be much much higher .',
#  ' ters for a large scale deep neural networks training and all these computation engines that you can see here they are essentially array of processing elements or or they are called systolic arrow based uh engines . These are just array of multiply and accumulate engines and to feed the huge number of processing engines you can . see 12 cross 14 multiplication engines that are being employed in one this is the first version of the tpu we are talking about and one scratch pad memory is deployed to just feed these data hungry uh process heads .',
#  ' These are in terms of milliwatt whereas the power consumed by these gpus are much more generalized . These are only for . fixed precision or mixed variation multiply and accumulate engines only for these processing engines and that is why they consume much more . less power as you can see here and of course uh the fpga based accelerators as i was mentioning that these areas that you saw you know in the ac based . accelerators they can be actually . configured or programmed into the accelerators .',
#  ' All these benchmarks are mostly to train your uh deep neural network benchmarks to be precise well from the market share point of view . These are the systems that are available nowadays now we are talking about a gap so this gap i or several times mentioned in the previous lessons we will just again go through this gap just to summarize whatever we have studied so what is the c gap .',
#  ' If you want to get linear increase in accuracy, you need to exponentially increase the computation density so this is the the take away from the left left hand side graph and the systems that are available we we know that mixed precision and different precision we can employ and we can have much more performance density but of course there is some limit and and we cannot go beyond certain limit of performance density right .',
#  ' ee in details in in the coming classes because we need to employ or or you need to implement them for for a particular target device right now the gap is there . The computational density is going high exponentially and the performance density is getting saturated so how we can accelerate some beyond certain so that is this course all about we will learn how to accelerate the ei benchmarks .',
#  ' You can learn about the memory systems the state of the memory technologies that are available nowadays and and and of course about the the basics of these neural networks the specific the specialized the specialized computation engine their performance and how this scaling happening from that algorithmic innovation point of view and how we can actually merge them to get better .']
